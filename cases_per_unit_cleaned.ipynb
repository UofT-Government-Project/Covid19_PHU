# %%
# Importing dependencies
import numpy as np
import pandas as pd
from pathlib import Path

# %%
# Reading file source
file_path = Path('Datasource/sample_covid_dataset.csv')
cases_df = pd.read_csv(file_path)
cases_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1     _id  Row_ID  \
# 0           0             9               9            353345  353346  353346
# 1           1            15              15             35074   35075   35075
# 2           2            16              16            131940  131941  131941
# 3           3            24              24            205768  205769  205769
# 4           4            26              26            387017  387018  387018
#
#   Accurate_Episode_Date   Case_Reported_Date   Test_Reported_Date  \
# 0   2020-12-14T00:00:00  2020-12-20T00:00:00  2020-12-20T00:00:00
# 1   2020-11-08T00:00:00  2020-11-09T00:00:00  2020-11-09T00:00:00
# 2   2021-02-03T00:00:00  2021-02-05T00:00:00  2021-02-05T00:00:00
# 3   2020-12-24T00:00:00  2020-12-29T00:00:00  2020-12-29T00:00:00
# 4   2021-01-21T00:00:00  2021-01-23T00:00:00  2021-01-23T00:00:00
#
#          Specimen_Date  ...  Outcome1 Outbreak_Related Reporting_PHU_ID  \
# ...

# %%
# checking details of dataframe
cases_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13524 entries, 0 to 13523
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 13524 non-null  int64
#  1   Unnamed: 0.1               13524 non-null  int64
#  2   Unnamed: 0.1.1             13524 non-null  int64
#  3   Unnamed: 0.1.1.1           13524 non-null  int64
#  4   _id                        13524 non-null  int64
#  5   Row_ID                     13524 non-null  int64
#  6   Accurate_Episode_Date      13524 non-null  object
#  7   Case_Reported_Date         13524 non-null  object
#  8   Test_Reported_Date         13524 non-null  object
#  9   Specimen_Date              13524 non-null  object
#  10  Age_Group                  13524 non-null  object
#  11  Client_Gender              13524 non-null  object
#  12  Case_AcquisitionInfo       13524 non-null  object
# ...

# %%
# dropping null values
cases_df.dropna()
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1     _id  \
# 0               0             9               9            353345  353346
# 1               1            15              15             35074   35075
# 2               2            16              16            131940  131941
# 3               3            24              24            205768  205769
# 4               4            26              26            387017  387018
# ...           ...           ...             ...               ...     ...
# 13519       13519         81805           81805            274226  274227
# 13520       13520         81806           81806            156061  156062
# 13521       13521         81807           81807             91595   91596
# 13522       13522         81808           81808             65609   65610
# 13523       13523         81819           81819            432399  432400
#
#        Row_ID Accurate_Episode_Date   Case_Reported_Date   Test_Reported_Date  \
# ...

# %%
# getting column names
cases_df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'Unnamed: 0.1.1.1',
#        '_id', 'Row_ID', 'Accurate_Episode_Date', 'Case_Reported_Date',
#        'Test_Reported_Date', 'Specimen_Date', 'Age_Group', 'Client_Gender',
#        'Case_AcquisitionInfo', 'Outcome1', 'Outbreak_Related',
#        'Reporting_PHU_ID', 'Reporting_PHU', 'Reporting_PHU_Address',
#        'Reporting_PHU_City', 'Reporting_PHU_Postal_Code',
#        'Reporting_PHU_Website', 'Reporting_PHU_Latitude',
#        'Reporting_PHU_Longitude'],
#       dtype='object')

# %%
# dropping unneccessary columns
PHU_cases_df = cases_df.drop(columns=['Unnamed: 0','Unnamed: 0.1','Unnamed: 0.1.1','Unnamed: 0.1.1.1','_id','Row_ID',
                'Accurate_Episode_Date','Test_Reported_Date','Specimen_Date','Case_AcquisitionInfo','Reporting_PHU_Address',
                'Reporting_PHU_City','Reporting_PHU_Postal_Code','Reporting_PHU_Website'])
PHU_cases_df
# Out:
#         Case_Reported_Date Age_Group Client_Gender  Outcome1 Outbreak_Related  \
# 0      2020-12-20T00:00:00       70s        FEMALE  Resolved              Yes
# 1      2020-11-09T00:00:00       <20        FEMALE  Resolved              Yes
# 2      2021-02-05T00:00:00       20s          MALE  Resolved              Yes
# 3      2020-12-29T00:00:00       20s          MALE  Resolved              Yes
# 4      2021-01-23T00:00:00       90+        FEMALE  Resolved              Yes
# ...                    ...       ...           ...       ...              ...
# 13519  2021-03-16T00:00:00       20s        FEMALE  Resolved              Yes
# 13520  2021-01-07T00:00:00       80s        FEMALE  Resolved              Yes
# 13521  2021-02-08T00:00:00       80s        FEMALE  Resolved              Yes
# 13522  2021-01-20T00:00:00       40s        FEMALE  Resolved              Yes
# 13523  2020-04-19T00:00:00       90+        FEMALE  Resolved              Yes
#
# ...

# %%
# renaming columns 
PHU_cases_df = PHU_cases_df.rename(columns={'Case_Reported_Date':'Case_Date', 'Client_Gender':'Gender', 'Outcome1':'Status',
                                   'Reporting_PHU_ID':'PHU_ID', 'Reporting_PHU':'PHU','Reporting_PHU_Latitude':'PHU_Lat',
                                   'Reporting_PHU_Longitude':'PHU_Long'}, inplace=False)
PHU_cases_df
# Out:
#                  Case_Date Age_Group  Gender    Status Outbreak_Related  \
# 0      2020-12-20T00:00:00       70s  FEMALE  Resolved              Yes
# 1      2020-11-09T00:00:00       <20  FEMALE  Resolved              Yes
# 2      2021-02-05T00:00:00       20s    MALE  Resolved              Yes
# 3      2020-12-29T00:00:00       20s    MALE  Resolved              Yes
# 4      2021-01-23T00:00:00       90+  FEMALE  Resolved              Yes
# ...                    ...       ...     ...       ...              ...
# 13519  2021-03-16T00:00:00       20s  FEMALE  Resolved              Yes
# 13520  2021-01-07T00:00:00       80s  FEMALE  Resolved              Yes
# 13521  2021-02-08T00:00:00       80s  FEMALE  Resolved              Yes
# 13522  2021-01-20T00:00:00       40s  FEMALE  Resolved              Yes
# 13523  2020-04-19T00:00:00       90+  FEMALE  Resolved              Yes
#
#        PHU_ID                                      PHU    PHU_Lat   PHU_Long
# ...

# %%
# extracting month, week, year from "Case_Date"
PHU_cases_df['Case_Month'] = pd.DatetimeIndex(PHU_cases_df['Case_Date']).month
PHU_cases_df['Case_Year']= pd.DatetimeIndex(PHU_cases_df['Case_Date']).year
PHU_cases_df
# Out:
#                  Case_Date Age_Group  Gender    Status Outbreak_Related  \
# 0      2020-12-20T00:00:00       70s  FEMALE  Resolved              Yes
# 1      2020-11-09T00:00:00       <20  FEMALE  Resolved              Yes
# 2      2021-02-05T00:00:00       20s    MALE  Resolved              Yes
# 3      2020-12-29T00:00:00       20s    MALE  Resolved              Yes
# 4      2021-01-23T00:00:00       90+  FEMALE  Resolved              Yes
# ...                    ...       ...     ...       ...              ...
# 13519  2021-03-16T00:00:00       20s  FEMALE  Resolved              Yes
# 13520  2021-01-07T00:00:00       80s  FEMALE  Resolved              Yes
# 13521  2021-02-08T00:00:00       80s  FEMALE  Resolved              Yes
# 13522  2021-01-20T00:00:00       40s  FEMALE  Resolved              Yes
# 13523  2020-04-19T00:00:00       90+  FEMALE  Resolved              Yes
#
#        PHU_ID                                      PHU    PHU_Lat   PHU_Long  \
# ...

# %%
# dropping "Case_Date" column
PHU_cases_df.drop(columns=['Case_Date'])
# Out:
#       Age_Group  Gender    Status Outbreak_Related  PHU_ID  \
# 0           70s  FEMALE  Resolved              Yes    3895
# 1           <20  FEMALE  Resolved              Yes    3895
# 2           20s    MALE  Resolved              Yes    2246
# 3           20s    MALE  Resolved              Yes    3895
# 4           90+  FEMALE  Resolved              Yes    2246
# ...         ...     ...       ...              ...     ...
# 13519       20s  FEMALE  Resolved              Yes    2253
# 13520       80s  FEMALE  Resolved              Yes    2261
# 13521       80s  FEMALE  Resolved              Yes    3895
# 13522       40s  FEMALE  Resolved              Yes    2253
# 13523       90+  FEMALE  Resolved              Yes    2253
#
#                                            PHU    PHU_Lat   PHU_Long  \
# 0                        Toronto Public Health  43.656591 -79.379358
# 1                        Toronto Public Health  43.656591 -79.379358
# ...

# %%
# saving cleaned dataset
output_file = Path('Datasource/clean_sample_covid_dataset.csv')
PHU_cases_df.to_csv(output_file, index=False)
