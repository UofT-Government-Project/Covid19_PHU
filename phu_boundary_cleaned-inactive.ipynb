# %%
# importing dependencies
import numpy as np
import pandas as pd
import pathlib as Path

# %%
# reading csv file
file_path = ('Datasource/Ministry_of_Health_Public_Health_Unit_Boundary.csv')
boundary_df = pd.read_csv(file_path)
boundary_df.head()
# Out:
#    FID    OGF_ID  PHU_ID                           NAME_ENG  \
# 0    1  71878062    2270          York Region Public Health
# 1    2  71878005    5183            Huron Perth Health Unit
# 2    3  71878059    2265  Region of Waterloo, Public Health
# 3    4  71878029    4913         Southwestern Public Health
# 4    5  71878057    2237    Hamilton Public Health Services
#
#                                        NAME_FR      GEO_UPD_DT  \
# 0        Service de santé de la région de York
# 1  Circonscription Sanitaire de Huron et Perth  20200515130357
# 2     Bureau de santé de la région de Waterloo
# 3                 Bureau de santé du Sud-Ouest  20200515130357
# 4       Services de santé publique de Hamilton
#
#          EFF_DATE   Shape__Area  Shape__Length
# 0  20200515125615  4.064927e+09  333012.606759
# 1  20200515125450  1.076427e+10  513599.959461
# 2  20200515125542  2.630598e+09  251873.983300
# 3  20200515125227  7.349576e+09  632592.443809
# ...

# %%
# checking details of dataframe
boundary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FID            34 non-null     int64
#  1   OGF_ID         34 non-null     int64
#  2   PHU_ID         34 non-null     int64
#  3   NAME_ENG       34 non-null     object
#  4   NAME_FR        34 non-null     object
#  5   GEO_UPD_DT     34 non-null     object
#  6   EFF_DATE       34 non-null     int64
#  7   Shape__Area    34 non-null     float64
#  8   Shape__Length  34 non-null     float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 2.5+ KB

# %%
# dropping inefficient columns
boundary_df.drop(columns=['FID','OGF_ID','NAME_FR','GEO_UPD_DT'])
# Out:
#     PHU_ID                                           NAME_ENG        EFF_DATE  \
# 0     2270                          York Region Public Health  20200515125615
# 1     5183                            Huron Perth Health Unit  20200515125450
# 2     2265                  Region of Waterloo, Public Health  20200515125542
# 3     4913                         Southwestern Public Health  20200515125227
# 4     2237                    Hamilton Public Health Services  20200515125524
# 5     2262                   Thunder Bay District Health Unit  20200515125918
# 6     2253                                 Peel Public Health  20200515125608
# 7     2242                              Lambton Public Health  20200515125111
# 8     2266             Wellington-Dufferin-Guelph Health Unit  20200515125552
# 9     2227                           Brant County Health Unit  20200515125534
# 10    2244                       Middlesex-London Health Unit  20200515125406
# ...
